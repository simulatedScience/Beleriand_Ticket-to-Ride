# %%
from constants import *
from copy import deepcopy
from random import shuffle

# %%
from game import Game

# %%
#try creating test game
test_config = DEFAULT_GAME_CONFIG
test_config['memory'] = 2

test_game = Game(n_players=3, config=test_config)

# %%
test_game.run(debug=True)
# Out:
# giving random cards
# laying out cards
# passing out first tickets
# 1/1 [==============================] - 4s 4s/step
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\future_D\private\programming\python\ticket_to_ride_ai\tickets_ai-master_by_mcandocia\test.ipynb Cell 4 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/future_D/private/programming/python/ticket_to_ride_ai/tickets_ai-master_by_mcandocia/test.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> test_game.run(debug=True)
#
# File c:\future_D\private\programming\python\ticket_to_ride_ai\tickets_ai-master_by_mcandocia\game.py:67, in Game.run(self, debug)
#      65 if debug:
#      66   print("passing out first tickets")
# ---> 67 self.pass_first_tickets()
#      68 while self.final_countdown > 0:
#      69   self.turn += 1
#
# File c:\future_D\private\programming\python\ticket_to_ride_ai\tickets_ai-master_by_mcandocia\game.py:138, in Game.pass_first_tickets(self)
#     136 def pass_first_tickets(self):
#     137   for player in self.players:
# --> 138     player.begin_selecting_tickets(min_tickets=2)
#
# File c:\future_D\private\programming\python\ticket_to_ride_ai\tickets_ai-master_by_mcandocia\player.py:181, in Player.begin_selecting_tickets(self, min_tickets)
#     179     self.finished_ticket(ticket, True)
#     180     n_already_chosen_tickets += 1
# --> 181 ticket_selection = self.ai.decide_on_tickets(
#     182     self, new_tickets, max(0, min_tickets - n_already_chosen_tickets))
#     183 ticket_indexes = [t['index'] for t in ticket_selection]
#     184 reject_tickets = [
#     185     ticket for ticket in new_tickets if ticket['index'] not in ticket_indexes]
#
# File c:\future_D\private\programming\python\ticket_to_ride_ai\tickets_ai-master_by_mcandocia\ai.py:285, in AI.decide_on_tickets(self, player, tickets, min_tickets)
#     282 # calculate probs and q-scores
#     283 probabilities = self.calculate_probabilities(
#     284     serializations, player, [y for x, y in ticket_serializations])
# --> 285 q_scores = self.calculate_q_scores(
#     286     serializations, player, [y for x, y in ticket_serializations])
#     288 decision_index = self.decide_based_on_p_and_q(
#     289     probabilities, q_scores, player)
#     291 # record history (with new ticket state)
#
# File c:\future_D\private\programming\python\ticket_to_ride_ai\tickets_ai-master_by_mcandocia\ai.py:401, in AI.calculate_q_scores(self, serializations, player, ticket_combos)
#     398   ticket_serialization = player.base_ticket_serialization[0]
#     399   n_serializations = len(serializations)
#     400   model_inputs = [np.vstack(serializations)] + vertical_repeat(
# --> 401       player.memories, n_serializations) + vertical_repeat(ticket_serialization, n_serializations)
#     402 else:
#     403   n_combos = len(ticket_combos)
#
# File c:\future_D\private\programming\python\ticket_to_ride_ai\tickets_ai-master_by_mcandocia\ai.py:438, in vertical_repeat(vec, n)
#     433 def vertical_repeat(vec, n):
#     434   """
#     435   given a list of numpy vectors, will repeat each element of the list vertically n times
#     436   this is used when serialized vectors are combined, and some need to be repeated for each combination of the other
#     437   """
# --> 438   return [v.reshape((1, len(v))).repeat(n, axis=0) for v in vec]
#
# File c:\future_D\private\programming\python\ticket_to_ride_ai\tickets_ai-master_by_mcandocia\ai.py:438, in <listcomp>(.0)
#     433 def vertical_repeat(vec, n):
#     434   """
#     435   given a list of numpy vectors, will repeat each element of the list vertically n times
#     436   this is used when serialized vectors are combined, and some need to be repeated for each combination of the other
#     437   """
# --> 438   return [v.reshape((1, len(v))).repeat(n, axis=0) for v in vec]
#
# AttributeError: 'list' object has no attribute 'reshape'

# %%
for player in test_game.players:
    print(player)
    print(player.trains)
# Out:
# player with 0/7 completed/uncompleted tickets, 11 train cards, 14 cars, and
# 		-46 total points
# defaultdict(<type 'int'>, {'blue': 1, 'pink': 0, 'yellow': 1, 'green': 2, 'orange': 2, 'black': 0, 'white': 2, 'locomotive': 1, 'red': 2})
# player with 0/7 completed/uncompleted tickets, 0 train cards, 0 cars, and
# 		-18 total points
# defaultdict(<type 'int'>, {'blue': 0, 'pink': 0, 'yellow': 0, 'black': 0, 'orange': 0, 'green': 0, 'white': 0, 'locomotive': 0, 'red': 0})
# player with 1/7 completed/uncompleted tickets, 3 train cards, 6 cars, and
# 		-31 total points
# defaultdict(<type 'int'>, {'pink': 0, 'blue': 0, 'yellow': 1, 'green': 0, 'orange': 0, 'black': 0, 'white': 1, 'locomotive': 0, 'red': 1})

# %%
# test model training
test_game.players[0].ai.train_win()
test_game.players[0].ai.train_q()

# %%
# try new game with existing players\
players = test_game.players
p0 = players[0]
p1 = players[1]
p2 = players[2]
player_wins = [[0,0,0] for _ in range(5)]

for n in range(5):
    print(f'------N={n}--------')
    for i in range(100):
        if i % 50 == 0:
            if i > 0:
                p1.ai.train_win(20)
                p1.ai.train_q(20)
                p2.ai.train_win()
                p2.ai.train_q()
        print(i)
        shuffle(players)
        game = Game(pre_existing_players = players, config=test_config)
        game.run(False)
        print(game)
        player_wins[n][0]+= p0.win
        player_wins[n][1]+= p1.win
        player_wins[n][2]+= p2.win
        for player in game.players:
            print(player)
    print('extended training...')
    p1.ai.train_win(100)
    p1.ai.train_q(100)
    p2.ai.train_win(50)
    p2.ai.train_q(50)
    print('resetting history...')
    p1.ai.reset_history()
    p2.ai.reset_history()
# Out:
# ------N=0--------
# 0
# ai.py:361: RuntimeWarning: invalid value encountered in divide
#   return selected/np.sum(selected)
# ai.py:334: RuntimeWarning: invalid value encountered in less
#   return np.random.choice(len(new_probs), p=new_probs)
# 3-player game on turn 211; winners: [1]
# player with 0/7 completed/uncompleted tickets, 21 train cards, 13 cars, and
# 		-63 total points
# player with 2/7 completed/uncompleted tickets, 7 train cards, 2 cars, and
# 		21 total points
# player with 2/7 completed/uncompleted tickets, 26 train cards, 23 cars, and
# 		-56 total points
# 1
# 3-player game on turn 253; winners: [1]
# player with 0/7 completed/uncompleted tickets, 65 train cards, 16 cars, and
# 		-35 total points
# player with 0/7 completed/uncompleted tickets, 7 train cards, 1 cars, and
# 		-32 total points
# player with 0/7 completed/uncompleted tickets, 6 train cards, 5 cars, and
# 		-39 total points
# 2
# 3-player game on turn 251; winners: [2]
# player with 0/7 completed/uncompleted tickets, 67 train cards, 27 cars, and
# 		-52 total points
# player with 0/7 completed/uncompleted tickets, 11 train cards, 4 cars, and
# 		-44 total points
# player with 0/7 completed/uncompleted tickets, 15 train cards, 1 cars, and
# 		-11 total points
# 3
# 3-player game on turn 233; winners: [2]
# player with 1/7 completed/uncompleted tickets, 12 train cards, 8 cars, and
# 		-18 total points
# player with 0/7 completed/uncompleted tickets, 21 train cards, 14 cars, and
# 		-41 total points
# player with 0/7 completed/uncompleted tickets, 10 train cards, 2 cars, and
# 		-16 total points
# 4
# 3-player game on turn 268; winners: [1]
# player with 0/7 completed/uncompleted tickets, 15 train cards, 2 cars, and
# 		-42 total points
# player with 1/7 completed/uncompleted tickets, 6 train cards, 1 cars, and
# 		-29 total points
# player with 0/7 completed/uncompleted tickets, 37 train cards, 18 cars, and
# 		-43 total points
# 5
# 3-player game on turn 234; winners: [0]
# player with 1/7 completed/uncompleted tickets, 6 train cards, 2 cars, and
# 		-30 total points
# player with 0/7 completed/uncompleted tickets, 82 train cards, 28 cars, and
# 		-61 total points
# player with 0/7 completed/uncompleted tickets, 12 train cards, 3 cars, and
# 		-49 total points
# 6
# 3-player game on turn 255; winners: [0]
# player with 0/7 completed/uncompleted tickets, 20 train cards, 0 cars, and
# 		13 total points
# player with 0/7 completed/uncompleted tickets, 18 train cards, 9 cars, and
# 		-41 total points
# player with 0/7 completed/uncompleted tickets, 65 train cards, 16 cars, and
# 		-37 total points
# 7
# 3-player game on turn 270; winners: [0]
# player with 0/7 completed/uncompleted tickets, 15 train cards, 0 cars, and
# 		-22 total points
# player with 0/7 completed/uncompleted tickets, 19 train cards, 6 cars, and
# 		-60 total points
# player with 0/7 completed/uncompleted tickets, 58 train cards, 19 cars, and
# 		-41 total points
# 8
# 3-player game on turn 247; winners: [2]
# player with 0/7 completed/uncompleted tickets, 68 train cards, 24 cars, and
# 		-50 total points
# player with 0/7 completed/uncompleted tickets, 3 train cards, 0 cars, and
# 		-42 total points
# player with 1/7 completed/uncompleted tickets, 24 train cards, 11 cars, and
# 		-9 total points
# 9
# 3-player game on turn 238; winners: [1]
# player with 1/7 completed/uncompleted tickets, 5 train cards, 6 cars, and
# 		-39 total points
# player with 0/7 completed/uncompleted tickets, 7 train cards, 0 cars, and
# 		-18 total points
# player with 0/7 completed/uncompleted tickets, 61 train cards, 23 cars, and
# 		-73 total points
# 10
# 3-player game on turn 263; winners: [2]
# player with 0/7 completed/uncompleted tickets, 28 train cards, 7 cars, and
# 		-45 total points
# player with 2/7 completed/uncompleted tickets, 54 train cards, 18 cars, and
# 		-45 total points
# player with 0/7 completed/uncompleted tickets, 0 train cards, 1 cars, and
# 		-11 total points
# 11
# 3-player game on turn 258; winners: [1]
# player with 0/7 completed/uncompleted tickets, 11 train cards, 1 cars, and
# 		-41 total points
# player with 0/7 completed/uncompleted tickets, 66 train cards, 15 cars, and
# 		-27 total points
# player with 0/7 completed/uncompleted tickets, 0 train cards, 8 cars, and
# 		-46 total points
# 12
# 3-player game on turn 224; winners: [2]
# player with 0/7 completed/uncompleted tickets, 46 train cards, 20 cars, and
# 		-53 total points
# player with 0/7 completed/uncompleted tickets, 6 train cards, 14 cars, and
# 		-50 total points
# player with 0/7 completed/uncompleted tickets, 17 train cards, 2 cars, and
# 		1 total points
# 13
# 3-player game on turn 234; winners: [1]
# player with 1/7 completed/uncompleted tickets, 15 train cards, 0 cars, and
# 		-29 total points
# player with 0/7 completed/uncompleted tickets, 30 train cards, 17 cars, and
# 		-20 total points
# player with 0/7 completed/uncompleted tickets, 58 train cards, 16 cars, and
# 		-45 total points
# 14
# 3-player game on turn 243; winners: [0]
# player with 0/7 completed/uncompleted tickets, 13 train cards, 2 cars, and
# 		-23 total points
# player with 1/7 completed/uncompleted tickets, 36 train cards, 26 cars, and
# 		-41 total points
# player with 0/7 completed/uncompleted tickets, 17 train cards, 8 cars, and
# 		-33 total points
# 15
# 3-player game on turn 275; winners: [0]
# player with 0/7 completed/uncompleted tickets, 69 train cards, 3 cars, and
# 		0 total points
# player with 0/7 completed/uncompleted tickets, 0 train cards, 3 cars, and
# 		-29 total points
# player with 1/7 completed/uncompleted tickets, 8 train cards, 0 cars, and
# 		-49 total points
# 16
# 3-player game on turn 228; winners: [0]
# player with 1/7 completed/uncompleted tickets, 10 train cards, 2 cars, and
# 		-19 total points
# player with 0/7 completed/uncompleted tickets, 8 train cards, 6 cars, and
# 		-34 total points
# player with 0/7 completed/uncompleted tickets, 35 train cards, 14 cars, and
# 		-50 total points
# 17
# 3-player game on turn 247; winners: [1]
# player with 0/7 completed/uncompleted tickets, 22 train cards, 9 cars, and
# 		-40 total points
# player with 2/7 completed/uncompleted tickets, 2 train cards, 0 cars, and
# 		-27 total points
# player with 0/7 completed/uncompleted tickets, 49 train cards, 19 cars, and
# 		-51 total points
# 18
# 3-player game on turn 273; winners: [1]
# player with 0/7 completed/uncompleted tickets, 17 train cards, 1 cars, and
# 		-27 total points
# player with 0/7 completed/uncompleted tickets, 64 train cards, 7 cars, and
# 		-20 total points
# player with 0/7 completed/uncompleted tickets, 14 train cards, 9 cars, and
# 		-31 total points
# 19
# 3-player game on turn 249; winners: [0]
# player with 0/7 completed/uncompleted tickets, 14 train cards, 1 cars, and
# 		-35 total points
# player with 1/7 completed/uncompleted tickets, 11 train cards, 13 cars, and
# 		-37 total points
# player with 0/7 completed/uncompleted tickets, 69 train cards, 15 cars, and
# 		-56 total points
# 20
# 3-player game on turn 258; winners: [0]
# player with 1/7 completed/uncompleted tickets, 7 train cards, 1 cars, and
# 		-30 total points
# player with 0/7 completed/uncompleted tickets, 10 train cards, 3 cars, and
# 		-30 total points
# player with 0/7 completed/uncompleted tickets, 27 train cards, 18 cars, and
# 		-43 total points
# 21
# 3-player game on turn 216; winners: [2]
# player with 0/7 completed/uncompleted tickets, 3 train cards, 1 cars, and
# 		-19 total points
# player with 1/6 completed/uncompleted tickets, 31 train cards, 15 cars, and
# 		-50 total points
# player with 0/7 completed/uncompleted tickets, 21 train cards, 13 cars, and
# 		-7 total points
# 22
# 3-player game on turn 210; winners: [1]
# player with 0/7 completed/uncompleted tickets, 1 train cards, 0 cars, and
# 		-26 total points
# player with 0/7 completed/uncompleted tickets, 20 train cards, 10 cars, and
# 		-22 total points
# player with 0/7 completed/uncompleted tickets, 58 train cards, 25 cars, and
# 		-50 total points
# 23
# 3-player game on turn 219; winners: [0]
# player with 0/7 completed/uncompleted tickets, 2 train cards, 0 cars, and
# 		-16 total points
# player with 0/7 completed/uncompleted tickets, 31 train cards, 11 cars, and
# 		-26 total points
# player with 0/7 completed/uncompleted tickets, 59 train cards, 25 cars, and
# 		-62 total points
# 24
# 3-player game on turn 216; winners: [0]
# player with 0/7 completed/uncompleted tickets, 6 train cards, 2 cars, and
# 		-31 total points
# player with 1/7 completed/uncompleted tickets, 2 train cards, 11 cars, and
# 		-49 total points
# player with 0/7 completed/uncompleted tickets, 17 train cards, 15 cars, and
# 		-61 total points
# 25
# 3-player game on turn 259; winners: [2]
# player with 0/7 completed/uncompleted tickets, 28 train cards, 6 cars, and
# 		-38 total points
# player with 0/7 completed/uncompleted tickets, 11 train cards, 2 cars, and
# 		-26 total points
# player with 0/7 completed/uncompleted tickets, 60 train cards, 10 cars, and
# 		-17 total points
# 26
# 3-player game on turn 248; winners: [1]
# player with 0/7 completed/uncompleted tickets, 36 train cards, 14 cars, and
# 		-51 total points
# player with 2/7 completed/uncompleted tickets, 11 train cards, 6 cars, and
# 		-15 total points
# player with 1/7 completed/uncompleted tickets, 12 train cards, 1 cars, and
# 		-24 total points
# 27
# 3-player game on turn 250; winners: [1]
# player with 0/7 completed/uncompleted tickets, 16 train cards, 4 cars, and
# 		-22 total points
# player with 1/7 completed/uncompleted tickets, 15 train cards, 2 cars, and
# 		-6 total points
# player with 1/7 completed/uncompleted tickets, 63 train cards, 22 cars, and
# 		-59 total points
# 28
# 3-player game on turn 216; winners: [2]
# player with 0/7 completed/uncompleted tickets, 5 train cards, 0 cars, and
# 		-18 total points
# player with 0/7 completed/uncompleted tickets, 75 train cards, 20 cars, and
# 		-48 total points
# player with 0/7 completed/uncompleted tickets, 15 train cards, 8 cars, and
# 		-10 total points
# 29
# 3-player game on turn 267; winners: [0]
# player with 1/7 completed/uncompleted tickets, 2 train cards, 1 cars, and
# 		-10 total points
# player with 0/7 completed/uncompleted tickets, 20 train cards, 9 cars, and
# 		-57 total points
# player with 0/7 completed/uncompleted tickets, 46 train cards, 11 cars, and
# 		-36 total points
# 30
# 3-player game on turn 260; winners: [1]
# player with 0/7 completed/uncompleted tickets, 62 train cards, 20 cars, and
# 		-47 total points
# player with 0/7 completed/uncompleted tickets, 19 train cards, 4 cars, and
# 		-26 total points
# player with 0/7 completed/uncompleted tickets, 15 train cards, 1 cars, and
# 		-29 total points
# 31
# 3-player game on turn 228; winners: [0]
# player with 0/7 completed/uncompleted tickets, 14 train cards, 1 cars, and
# 		-7 total points
# player with 0/7 completed/uncompleted tickets, 22 train cards, 13 cars, and
# 		-40 total points
# player with 1/7 completed/uncompleted tickets, 33 train cards, 18 cars, and
# 		-69 total points
# 32
# 3-player game on turn 251; winners: [0]
# player with 1/7 completed/uncompleted tickets, 24 train cards, 5 cars, and
# 		-20 total points
# player with 0/7 completed/uncompleted tickets, 57 train cards, 22 cars, and
# 		-43 total points
# player with 1/7 completed/uncompleted tickets, 16 train cards, 0 cars, and
# 		-27 total points
# 33
# 3-player game on turn 254; winners: [2]
# player with 0/7 completed/uncompleted tickets, 61 train cards, 16 cars, and
# 		-32 total points
# player with 0/7 completed/uncompleted tickets, 25 train cards, 2 cars, and
# 		-28 total points
# player with 2/7 completed/uncompleted tickets, 3 train cards, 2 cars, and
# 		-17 total points
# 34
# 3-player game on turn 224; winners: [2]
# player with 0/7 completed/uncompleted tickets, 15 train cards, 6 cars, and
# 		-32 total points
# player with 0/7 completed/uncompleted tickets, 74 train cards, 31 cars, and
# 		-55 total points
# player with 0/7 completed/uncompleted tickets, 4 train cards, 2 cars, and
# 		-14 total points
# 35
# 3-player game on turn 232; winners: [1]
# player with 0/7 completed/uncompleted tickets, 68 train cards, 26 cars, and
# 		-67 total points
# player with 1/7 completed/uncompleted tickets, 15 train cards, 0 cars, and
# 		-15 total points
# player with 0/7 completed/uncompleted tickets, 16 train cards, 9 cars, and
# 		-43 total points
# 36
# 3-player game on turn 216; winners: [0]
# player with 0/7 completed/uncompleted tickets, 22 train cards, 1 cars, and
# 		-5 total points
# player with 0/7 completed/uncompleted tickets, 56 train cards, 22 cars, and
# 		-42 total points
# player with 0/7 completed/uncompleted tickets, 14 train cards, 18 cars, and
# 		-46 total points
# 37
# 3-player game on turn 211; winners: [1]
# player with 0/7 completed/uncompleted tickets, 25 train cards, 9 cars, and
# 		-45 total points
# player with 1/6 completed/uncompleted tickets, 15 train cards, 0 cars, and
# 		9 total points
# player with 0/7 completed/uncompleted tickets, 39 train cards, 22 cars, and
# 		-51 total points
# 38
# 3-player game on turn 245; winners: [2]
# player with 0/7 completed/uncompleted tickets, 14 train cards, 10 cars, and
# 		-40 total points
# player with 0/7 completed/uncompleted tickets, 43 train cards, 19 cars, and
# 		-47 total points
# player with 0/7 completed/uncompleted tickets, 13 train cards, 2 cars, and
# 		-23 total points
# 39
# 3-player game on turn 232; winners: [0]
# player with 0/7 completed/uncompleted tickets, 1 train cards, 4 cars, and
# 		-27 total points
# player with 0/7 completed/uncompleted tickets, 9 train cards, 1 cars, and
# 		-48 total points
# player with 1/6 completed/uncompleted tickets, 53 train cards, 22 cars, and
# 		-38 total points
# 40
# 3-player game on turn 253; winners: [2]
# player with 0/7 completed/uncompleted tickets, 31 train cards, 13 cars, and
# 		-48 total points
# player with 0/7 completed/uncompleted tickets, 3 train cards, 1 cars, and
# 		-46 total points
# player with 1/7 completed/uncompleted tickets, 57 train cards, 15 cars, and
# 		-15 total points
# 41
# 3-player game on turn 216; winners: [1]
# player with 0/7 completed/uncompleted tickets, 13 train cards, 0 cars, and
# 		-26 total points
# player with 0/7 completed/uncompleted tickets, 4 train cards, 6 cars, and
# 		-20 total points
# player with 0/7 completed/uncompleted tickets, 22 train cards, 16 cars, and
# 		-76 total points
# 42
# 3-player game on turn 269; winners: [1]
# player with 0/7 completed/uncompleted tickets, 29 train cards, 3 cars, and
# 		-37 total points
# player with 0/7 completed/uncompleted tickets, 60 train cards, 17 cars, and
# 		-24 total points
# player with 1/7 completed/uncompleted tickets, 4 train cards, 2 cars, and
# 		-49 total points
# 43
# 3-player game on turn 307; winners: [1]
# player with 2/7 completed/uncompleted tickets, 26 train cards, 5 cars, and
# 		-15 total points
# player with 0/7 completed/uncompleted tickets, 66 train cards, 1 cars, and
# 		-13 total points
# player with 0/7 completed/uncompleted tickets, 11 train cards, 4 cars, and
# 		-52 total points
# 44
# 3-player game on turn 263; winners: [0]
# player with 0/7 completed/uncompleted tickets, 9 train cards, 1 cars, and
# 		-12 total points
# player with 0/7 completed/uncompleted tickets, 55 train cards, 21 cars, and
# 		-42 total points
# player with 1/7 completed/uncompleted tickets, 19 train cards, 2 cars, and
# 		-15 total points
# 45
# 3-player game on turn 244; winners: [1]
# player with 0/7 completed/uncompleted tickets, 81 train cards, 25 cars, and
# 		-42 total points
# player with 1/7 completed/uncompleted tickets, 10 train cards, 1 cars, and
# 		-24 total points
# player with 0/7 completed/uncompleted tickets, 7 train cards, 3 cars, and
# 		-41 total points
# 46
# 3-player game on turn 229; winners: [2]
# player with 1/7 completed/uncompleted tickets, 32 train cards, 21 cars, and
# 		-55 total points
# player with 0/7 completed/uncompleted tickets, 21 train cards, 2 cars, and
# 		-34 total points
# player with 0/7 completed/uncompleted tickets, 10 train cards, 5 cars, and
# 		-17 total points
# 47
# 3-player game on turn 238; winners: [2]
# player with 0/7 completed/uncompleted tickets, 73 train cards, 22 cars, and
# 		-33 total points
# player with 0/7 completed/uncompleted tickets, 13 train cards, 1 cars, and
# 		-44 total points
# player with 0/7 completed/uncompleted tickets, 17 train cards, 3 cars, and
# 		-16 total points
# 48
# 3-player game on turn 265; winners: [1]
# player with 1/7 completed/uncompleted tickets, 28 train cards, 13 cars, and
# 		-54 total points
# player with 0/7 completed/uncompleted tickets, 5 train cards, 0 cars, and
# 		-12 total points
# player with 0/7 completed/uncompleted tickets, 27 train cards, 16 cars, and
# 		-29 total points
# 49
# 3-player game on turn 216; winners: [0]
# player with 0/7 completed/uncompleted tickets, 10 train cards, 0 cars, and
# 		-17 total points
# player with 0/7 completed/uncompleted tickets, 1 train cards, 6 cars, and
# 		-22 total points
# player with 0/7 completed/uncompleted tickets, 29 train cards, 19 cars, and
# 		-44 total points
# 50
# 3-player game on turn 291; winners: [1]
# player with 0/7 completed/uncompleted tickets, 15 train cards, 0 cars, and
# 		-22 total points
# player with 1/7 completed/uncompleted tickets, 16 train cards, 5 cars, and
# 		-15 total points
# player with 0/7 completed/uncompleted tickets, 49 train cards, 14 cars, and
# 		-41 total points
# 51
# 3-player game on turn 262; winners: [1]
# player with 0/7 completed/uncompleted tickets, 52 train cards, 11 cars, and
# 		-35 total points
# player with 1/7 completed/uncompleted tickets, 16 train cards, 1 cars, and
# 		-13 total points
# player with 0/7 completed/uncompleted tickets, 34 train cards, 16 cars, and
# 		-53 total points
# 52
# 3-player game on turn 273; winners: [1]
# player with 0/7 completed/uncompleted tickets, 16 train cards, 1 cars, and
# 		-45 total points
# player with 0/7 completed/uncompleted tickets, 34 train cards, 10 cars, and
# 		-7 total points
# player with 1/7 completed/uncompleted tickets, 52 train cards, 4 cars, and
# 		-30 total points
# 53
# 3-player game on turn 270; winners: [1]
# player with 0/7 completed/uncompleted tickets, 23 train cards, 0 cars, and
# 		-25 total points
# player with 1/7 completed/uncompleted tickets, 17 train cards, 3 cars, and
# 		-11 total points
# player with 0/7 completed/uncompleted tickets, 63 train cards, 8 cars, and
# 		-37 total points
# 54
# 3-player game on turn 283; winners: [1]
# player with 0/7 completed/uncompleted tickets, 13 train cards, 3 cars, and
# 		-29 total points
# player with 1/7 completed/uncompleted tickets, 29 train cards, 0 cars, and
# 		-5 total points
# player with 0/7 completed/uncompleted tickets, 59 train cards, 19 cars, and
# 		-43 total points
# 55
# 3-player game on turn 230; winners: [2]
# player with 0/7 completed/uncompleted tickets, 61 train cards, 16 cars, and
# 		-41 total points
# player with 0/7 completed/uncompleted tickets, 26 train cards, 4 cars, and
# 		-22 total points
# player with 0/7 completed/uncompleted tickets, 14 train cards, 0 cars, and
# 		-19 total points
# 56
# 3-player game on turn 256; winners: [0]
# player with 1/7 completed/uncompleted tickets, 14 train cards, 0 cars, and
# 		-1 total points
# player with 1/7 completed/uncompleted tickets, 25 train cards, 2 cars, and
# 		-8 total points
# player with 0/7 completed/uncompleted tickets, 62 train cards, 15 cars, and
# 		-30 total points
# 57
# 3-player game on turn 233; winners: [1]
# player with 0/7 completed/uncompleted tickets, 7 train cards, 13 cars, and
# 		-44 total points
# player with 0/7 completed/uncompleted tickets, 44 train cards, 22 cars, and
# 		-27 total points
# player with 1/7 completed/uncompleted tickets, 11 train cards, 0 cars, and
# 		-31 total points
# 58
# 3-player game on turn 235; winners: [1]
# player with 1/7 completed/uncompleted tickets, 25 train cards, 11 cars, and
# 		-41 total points
# player with 0/7 completed/uncompleted tickets, 11 train cards, 1 cars, and
# 		-22 total points
# player with 0/7 completed/uncompleted tickets, 9 train cards, 9 cars, and
# 		-36 total points
# 59
# 3-player game on turn 277; winners: [1]
# player with 1/7 completed/uncompleted tickets, 49 train cards, 12 cars, and
# 		-18 total points
# player with 0/7 completed/uncompleted tickets, 42 train cards, 1 cars, and
# 		-14 total points
# player with 0/7 completed/uncompleted tickets, 11 train cards, 3 cars, and
# 		-24 total points
# 60
# 3-player game on turn 232; winners: [1]
# player with 0/7 completed/uncompleted tickets, 49 train cards, 16 cars, and
# 		-44 total points
# player with 0/7 completed/uncompleted tickets, 22 train cards, 0 cars, and
# 		-8 total points
# player with 0/7 completed/uncompleted tickets, 30 train cards, 15 cars, and
# 		-27 total points
# 61
# 3-player game on turn 229; winners: [2]
# player with 0/7 completed/uncompleted tickets, 51 train cards, 9 cars, and
# 		-28 total points
# player with 0/7 completed/uncompleted tickets, 13 train cards, 2 cars, and
# 		-20 total points
# player with 0/7 completed/uncompleted tickets, 37 train cards, 8 cars, and
# 		-6 total points
# 62
# 3-player game on turn 250; winners: [1]
# player with 0/7 completed/uncompleted tickets, 55 train cards, 17 cars, and
# 		-33 total points
# player with 0/7 completed/uncompleted tickets, 17 train cards, 2 cars, and
# 		-8 total points
# player with 2/7 completed/uncompleted tickets, 29 train cards, 12 cars, and
# 		-30 total points
# 63
# 3-player game on turn 264; winners: [1]
# player with 1/7 completed/uncompleted tickets, 15 train cards, 1 cars, and
# 		-20 total points
# player with 0/7 completed/uncompleted tickets, 25 train cards, 5 cars, and
# 		-18 total points
# player with 1/7 completed/uncompleted tickets, 62 train cards, 12 cars, and
# 		-20 total points
# 64
# 3-player game on turn 270; winners: [0]
# player with 0/7 completed/uncompleted tickets, 27 train cards, 0 cars, and
# 		-17 total points
# player with 0/7 completed/uncompleted tickets, 60 train cards, 11 cars, and
# 		-46 total points
# player with 1/7 completed/uncompleted tickets, 14 train cards, 1 cars, and
# 		-18 total points
# 65
# 3-player game on turn 293; winners: [2]
# player with 0/7 completed/uncompleted tickets, 60 train cards, 14 cars, and
# 		-57 total points
# player with 0/7 completed/uncompleted tickets, 27 train cards, 8 cars, and
# 		-24 total points
# player with 0/7 completed/uncompleted tickets, 14 train cards, 1 cars, and
# 		-15 total points
# 66
# 3-player game on turn 285; winners: [2]
# player with 1/7 completed/uncompleted tickets, 23 train cards, 1 cars, and
# 		-29 total points
# player with 0/7 completed/uncompleted tickets, 52 train cards, 3 cars, and
# 		-26 total points
# player with 0/7 completed/uncompleted tickets, 27 train cards, 5 cars, and
# 		-8 total points
# 67
# 3-player game on turn 238; winners: [1]
# player with 0/7 completed/uncompleted tickets, 44 train cards, 9 cars, and
# 		-32 total points
# player with 0/7 completed/uncompleted tickets, 43 train cards, 0 cars, and
# 		-11 total points
# player with 0/7 completed/uncompleted tickets, 16 train cards, 6 cars, and
# 		-36 total points
# 68
# 3-player game on turn 252; winners: [0]
# player with 1/7 completed/uncompleted tickets, 15 train cards, 0 cars, and
# 		-11 total points
# player with 0/7 completed/uncompleted tickets, 14 train cards, 7 cars, and
# 		-36 total points
# player with 0/7 completed/uncompleted tickets, 43 train cards, 14 cars, and
# 		-36 total points
# 69
# 3-player game on turn 256; winners: [1]
# player with 1/7 completed/uncompleted tickets, 44 train cards, 16 cars, and
# 		-38 total points
# player with 0/7 completed/uncompleted tickets, 12 train cards, 1 cars, and
# 		-20 total points
# player with 0/7 completed/uncompleted tickets, 2 train cards, 11 cars, and
# 		-49 total points
# 70
# 3-player game on turn 243; winners: [0]
# player with 1/7 completed/uncompleted tickets, 16 train cards, 2 cars, and
# 		-15 total points
# player with 0/7 completed/uncompleted tickets, 28 train cards, 11 cars, and
# 		-48 total points
# player with 1/7 completed/uncompleted tickets, 57 train cards, 20 cars, and
# 		-47 total points
# 71
# 3-player game on turn 279; winners: [0]
# player with 1/7 completed/uncompleted tickets, 27 train cards, 0 cars, and
# 		-20 total points
# player with 1/7 completed/uncompleted tickets, 56 train cards, 10 cars, and
# 		-34 total points
# player with 0/7 completed/uncompleted tickets, 19 train cards, 3 cars, and
# 		-46 total points
# 72
# 3-player game on turn 272; winners: [0]
# player with 1/7 completed/uncompleted tickets, 22 train cards, 8 cars, and
# 		-19 total points
# player with 0/7 completed/uncompleted tickets, 54 train cards, 11 cars, and
# 		-47 total points
# player with 0/7 completed/uncompleted tickets, 25 train cards, 2 cars, and
# 		-40 total points
# 73
# 3-player game on turn 259; winners: [2]
# player with 0/7 completed/uncompleted tickets, 67 train cards, 23 cars, and
# 		-47 total points
# player with 0/7 completed/uncompleted tickets, 13 train cards, 1 cars, and
# 		-28 total points
# player with 0/7 completed/uncompleted tickets, 22 train cards, 9 cars, and
# 		-18 total points
# 74
# 3-player game on turn 280; winners: [0]
# player with 1/7 completed/uncompleted tickets, 56 train cards, 8 cars, and
# 		-16 total points
# player with 0/7 completed/uncompleted tickets, 8 train cards, 0 cars, and
# 		-38 total points
# player with 0/7 completed/uncompleted tickets, 37 train cards, 4 cars, and
# 		-37 total points
# 75
# 3-player game on turn 242; winners: [1]
# player with 0/7 completed/uncompleted tickets, 51 train cards, 17 cars, and
# 		-16 total points
# player with 0/7 completed/uncompleted tickets, 47 train cards, 14 cars, and
# 		-11 total points
# player with 0/7 completed/uncompleted tickets, 3 train cards, 1 cars, and
# 		-44 total points
# 76
# 3-player game on turn 299; winners: [2]
# player with 0/7 completed/uncompleted tickets, 19 train cards, 4 cars, and
# 		-28 total points
# player with 0/7 completed/uncompleted tickets, 61 train cards, 14 cars, and
# 		-47 total points
# player with 2/7 completed/uncompleted tickets, 22 train cards, 0 cars, and
# 		-3 total points
# 77
# 3-player game on turn 223; winners: [1]
# player with 0/7 completed/uncompleted tickets, 57 train cards, 20 cars, and
# 		-21 total points
# player with 0/7 completed/uncompleted tickets, 21 train cards, 0 cars, and
# 		10 total points
# player with 0/7 completed/uncompleted tickets, 24 train cards, 15 cars, and
# 		-39 total points
# 78
# 3-player game on turn 247; winners: [0]
# player with 1/7 completed/uncompleted tickets, 20 train cards, 8 cars, and
# 		-1 total points
# player with 0/7 completed/uncompleted tickets, 38 train cards, 1 cars, and
# 		-11 total points
# player with 0/7 completed/uncompleted tickets, 45 train cards, 16 cars, and
# 		-41 total points
# 79
# 3-player game on turn 251; winners: [1]
# player with 0/7 completed/uncompleted tickets, 58 train cards, 16 cars, and
# 		-46 total points
# player with 1/7 completed/uncompleted tickets, 27 train cards, 10 cars, and
# 		-12 total points
# player with 0/7 completed/uncompleted tickets, 16 train cards, 1 cars, and
# 		-24 total points
# 80
# 3-player game on turn 316; winners: [0]
# player with 0/7 completed/uncompleted tickets, 13 train cards, 3 cars, and
# 		-18 total points
# player with 1/7 completed/uncompleted tickets, 36 train cards, 0 cars, and
# 		-19 total points
# player with 0/7 completed/uncompleted tickets, 53 train cards, 3 cars, and
# 		-41 total points
# 81
# 3-player game on turn 251; winners: [2]
# player with 0/7 completed/uncompleted tickets, 41 train cards, 8 cars, and
# 		-24 total points
# player with 0/7 completed/uncompleted tickets, 39 train cards, 11 cars, and
# 		-36 total points
# player with 1/7 completed/uncompleted tickets, 21 train cards, 1 cars, and
# 		-14 total points
# 82
# 3-player game on turn 231; winners: [0]
# player with 0/7 completed/uncompleted tickets, 26 train cards, 2 cars, and
# 		1 total points
# player with 0/7 completed/uncompleted tickets, 59 train cards, 9 cars, and
# 		-44 total points
# player with 0/7 completed/uncompleted tickets, 16 train cards, 4 cars, and
# 		-8 total points
# 83
# 3-player game on turn 268; winners: [1]
# player with 1/7 completed/uncompleted tickets, 55 train cards, 18 cars, and
# 		-38 total points
# player with 0/7 completed/uncompleted tickets, 13 train cards, 1 cars, and
# 		4 total points
# player with 0/7 completed/uncompleted tickets, 22 train cards, 6 cars, and
# 		-23 total points
# 84
# 3-player game on turn 246; winners: [1]
# player with 0/7 completed/uncompleted tickets, 10 train cards, 0 cars, and
# 		-39 total points
# player with 1/7 completed/uncompleted tickets, 45 train cards, 14 cars, and
# 		-16 total points
# player with 0/7 completed/uncompleted tickets, 47 train cards, 14 cars, and
# 		-34 total points
# 85
# 3-player game on turn 281; winners: [0]
# player with 1/7 completed/uncompleted tickets, 35 train cards, 3 cars, and
# 		-3 total points
# player with 0/7 completed/uncompleted tickets, 55 train cards, 8 cars, and
# 		-56 total points
# player with 1/7 completed/uncompleted tickets, 12 train cards, 1 cars, and
# 		-15 total points
# 86
# 3-player game on turn 251; winners: [2]
# player with 0/7 completed/uncompleted tickets, 11 train cards, 16 cars, and
# 		-45 total points
# player with 0/7 completed/uncompleted tickets, 26 train cards, 13 cars, and
# 		-30 total points
# player with 0/7 completed/uncompleted tickets, 6 train cards, 0 cars, and
# 		-26 total points
# 87
# 3-player game on turn 262; winners: [1]
# player with 0/7 completed/uncompleted tickets, 58 train cards, 13 cars, and
# 		-45 total points
# player with 1/7 completed/uncompleted tickets, 15 train cards, 0 cars, and
# 		-10 total points
# player with 0/7 completed/uncompleted tickets, 29 train cards, 8 cars, and
# 		-55 total points
# 88
# 3-player game on turn 242; winners: [1]
# player with 0/7 completed/uncompleted tickets, 45 train cards, 12 cars, and
# 		-39 total points
# player with 1/7 completed/uncompleted tickets, 25 train cards, 12 cars, and
# 		-28 total points
# player with 0/7 completed/uncompleted tickets, 7 train cards, 2 cars, and
# 		-42 total points
# 89
# 3-player game on turn 262; winners: [2]
# player with 0/7 completed/uncompleted tickets, 56 train cards, 10 cars, and
# 		-56 total points
# player with 2/7 completed/uncompleted tickets, 22 train cards, 2 cars, and
# 		-31 total points
# player with 0/7 completed/uncompleted tickets, 23 train cards, 4 cars, and
# 		9 total points
# 90
# 3-player game on turn 256; winners: [1]
# player with 0/7 completed/uncompleted tickets, 26 train cards, 8 cars, and
# 		-41 total points
# player with 0/7 completed/uncompleted tickets, 8 train cards, 2 cars, and
# 		-21 total points
# player with 1/7 completed/uncompleted tickets, 42 train cards, 18 cars, and
# 		-32 total points
# 91
# 3-player game on turn 271; winners: [0]
# player with 0/7 completed/uncompleted tickets, 11 train cards, 5 cars, and
# 		-1 total points
# player with 0/7 completed/uncompleted tickets, 15 train cards, 2 cars, and
# 		-29 total points
# player with 0/7 completed/uncompleted tickets, 51 train cards, 15 cars, and
# 		-50 total points
# 92
# 3-player game on turn 298; winners: [1]
# player with 0/7 completed/uncompleted tickets, 56 train cards, 11 cars, and
# 		-61 total points
# player with 1/7 completed/uncompleted tickets, 14 train cards, 2 cars, and
# 		-3 total points
# player with 0/7 completed/uncompleted tickets, 26 train cards, 7 cars, and
# 		-31 total points
# 93
# 3-player game on turn 256; winners: [1]
# player with 0/7 completed/uncompleted tickets, 50 train cards, 13 cars, and
# 		-30 total points
# player with 1/7 completed/uncompleted tickets, 9 train cards, 1 cars, and
# 		-23 total points
# player with 0/7 completed/uncompleted tickets, 18 train cards, 18 cars, and
# 		-63 total points
# 94
# 3-player game on turn 243; winners: [0]
# player with 1/7 completed/uncompleted tickets, 14 train cards, 1 cars, and
# 		-1 total points
# player with 0/7 completed/uncompleted tickets, 37 train cards, 3 cars, and
# 		-13 total points
# player with 0/7 completed/uncompleted tickets, 51 train cards, 6 cars, and
# 		-21 total points
# 95
# 3-player game on turn 273; winners: [0]
# player with 0/7 completed/uncompleted tickets, 5 train cards, 1 cars, and
# 		-23 total points
# player with 0/7 completed/uncompleted tickets, 14 train cards, 7 cars, and
# 		-24 total points
# player with 1/7 completed/uncompleted tickets, 48 train cards, 14 cars, and
# 		-46 total points
# 96
# 3-player game on turn 252; winners: [0]
# player with 0/7 completed/uncompleted tickets, 24 train cards, 2 cars, and
# 		-23 total points
# player with 0/7 completed/uncompleted tickets, 13 train cards, 10 cars, and
# 		-26 total points
# player with 0/7 completed/uncompleted tickets, 40 train cards, 17 cars, and
# 		-24 total points
# 97
# 3-player game on turn 261; winners: [0]
# player with 0/7 completed/uncompleted tickets, 9 train cards, 0 cars, and
# 		-10 total points
# player with 1/7 completed/uncompleted tickets, 0 train cards, 8 cars, and
# 		-25 total points
# player with 0/7 completed/uncompleted tickets, 25 train cards, 14 cars, and
# 		-28 total points
# 98
# 3-player game on turn 262; winners: [0]
# player with 1/7 completed/uncompleted tickets, 28 train cards, 4 cars, and
# 		3 total points
# player with 2/7 completed/uncompleted tickets, 22 train cards, 0 cars, and
# 		-18 total points
# player with 0/7 completed/uncompleted tickets, 52 train cards, 11 cars, and
# 		-25 total points
# 99
# 3-player game on turn 264; winners: [1]
# player with 0/7 completed/uncompleted tickets, 18 train cards, 1 cars, and
# 		-36 total points
# player with 0/7 completed/uncompleted tickets, 29 train cards, 4 cars, and
# 		-21 total points
# player with 0/7 completed/uncompleted tickets, 54 train cards, 17 cars, and
# 		-31 total points
# extended training...
# resetting history...
# ------N=1--------
# 0
# 3-player game on turn 270; winners: [0]
# player with 0/7 completed/uncompleted tickets, 16 train cards, 0 cars, and
# 		-5 total points
# player with 2/7 completed/uncompleted tickets, 53 train cards, 10 cars, and
# 		-19 total points
# player with 1/7 completed/uncompleted tickets, 33 train cards, 10 cars, and
# 		-33 total points
# 1
# 3-player game on turn 237; winners: [0]
# player with 0/7 completed/uncompleted tickets, 11 train cards, 1 cars, and
# 		-10 total points
# player with 0/7 completed/uncompleted tickets, 5 train cards, 6 cars, and
# 		-38 total points
# player with 1/7 completed/uncompleted tickets, 35 train cards, 18 cars, and
# 		-39 total points
# 2
# 3-player game on turn 230; winners: [2]
# player with 1/7 completed/uncompleted tickets, 28 train cards, 12 cars, and
# 		-56 total points
# player with 0/7 completed/uncompleted tickets, 47 train cards, 6 cars, and
# 		-24 total points
# player with 1/7 completed/uncompleted tickets, 27 train cards, 0 cars, and
# 		0 total points
# 3
# 3-player game on turn 261; winners: [1]
# player with 0/7 completed/uncompleted tickets, 25 train cards, 2 cars, and
# 		-20 total points
# player with 0/7 completed/uncompleted tickets, 18 train cards, 5 cars, and
# 		-16 total points
# player with 0/7 completed/uncompleted tickets, 58 train cards, 15 cars, and
# 		-38 total points
# 4
# 3-player game on turn 283; winners: [0]
# player with 0/7 completed/uncompleted tickets, 51 train cards, 4 cars, and
# 		-8 total points
# player with 0/7 completed/uncompleted tickets, 8 train cards, 0 cars, and
# 		-10 total points
# player with 0/7 completed/uncompleted tickets, 42 train cards, 5 cars, and
# 		-35 total points
# 5
# 3-player game on turn 278; winners: [1]
# player with 1/7 completed/uncompleted tickets, 58 train cards, 10 cars, and
# 		-51 total points
# player with 0/7 completed/uncompleted tickets, 23 train cards, 1 cars, and
# 		-9 total points
# player with 0/7 completed/uncompleted tickets, 20 train cards, 1 cars, and
# 		-27 total points
# 6
# 3-player game on turn 254; winners: [1]
# player with 0/7 completed/uncompleted tickets, 56 train cards, 11 cars, and
# 		-39 total points
# player with 1/7 completed/uncompleted tickets, 26 train cards, 3 cars, and
# 		-1 total points
# player with 0/7 completed/uncompleted tickets, 20 train cards, 0 cars, and
# 		-18 total points
# 7
# 3-player game on turn 237; winners: [0]
# player with 0/7 completed/uncompleted tickets, 23 train cards, 2 cars, and
# 		-12 total points
# player with 1/7 completed/uncompleted tickets, 31 train cards, 13 cars, and
# 		-18 total points
# player with 0/7 completed/uncompleted tickets, 48 train cards, 13 cars, and
# 		-55 total points
# 8
# 3-player game on turn 243; winners: [0]
# player with 0/7 completed/uncompleted tickets, 10 train cards, 1 cars, and
# 		-15 total points
# player with 0/7 completed/uncompleted tickets, 17 train cards, 13 cars, and
# 		-32 total points
# player with 0/7 completed/uncompleted tickets, 39 train cards, 20 cars, and
# 		-50 total points
# 9
# 3-player game on turn 262; winners: [1]
# player with 0/7 completed/uncompleted tickets, 48 train cards, 8 cars, and
# 		-34 total points
# player with 1/7 completed/uncompleted tickets, 13 train cards, 0 cars, and
# 		-14 total points
# player with 0/7 completed/uncompleted tickets, 39 train cards, 6 cars, and
# 		-24 total points
# 10
# 3-player game on turn 262; winners: [1]
# player with 0/7 completed/uncompleted tickets, 60 train cards, 5 cars, and
# 		-25 total points
# player with 1/7 completed/uncompleted tickets, 23 train cards, 0 cars, and
# 		5 total points
# player with 0/7 completed/uncompleted tickets, 20 train cards, 4 cars, and
# 		-29 total points
# 11
# 3-player game on turn 264; winners: [2]
# player with 0/7 completed/uncompleted tickets, 22 train cards, 1 cars, and
# 		-27 total points
# player with 0/7 completed/uncompleted tickets, 58 train cards, 8 cars, and
# 		-25 total points
# player with 0/7 completed/uncompleted tickets, 21 train cards, 8 cars, and
# 		-23 total points
# 12
# 3-player game on turn 238; winners: [1]
# player with 1/7 completed/uncompleted tickets, 24 train cards, 11 cars, and
# 		-41 total points
# player with 1/7 completed/uncompleted tickets, 19 train cards, 1 cars, and
# 		7 total points
# player with 0/7 completed/uncompleted tickets, 59 train cards, 20 cars, and
# 		-51 total points
# 13
# 3-player game on turn 262; winners: [2]
# player with 0/7 completed/uncompleted tickets, 50 train cards, 16 cars, and
# 		-42 total points
# player with 0/7 completed/uncompleted tickets, 12 train cards, 2 cars, and
# 		-31 total points
# player with 1/7 completed/uncompleted tickets, 40 train cards, 10 cars, and
# 		-4 total points
# 14
# 3-player game on turn 246; winners: [0]
# player with 0/7 completed/uncompleted tickets, 12 train cards, 0 cars, and
# 		-8 total points
# player with 0/7 completed/uncompleted tickets, 65 train cards, 17 cars, and
# 		-57 total points
# player with 0/7 completed/uncompleted tickets, 25 train cards, 6 cars, and
# 		-17 total points
# 15
# 3-player game on turn 268; winners: [1]
# player with 1/7 completed/uncompleted tickets, 18 train cards, 3 cars, and
# 		-18 total points
# player with 2/7 completed/uncompleted tickets, 33 train cards, 1 cars, and
# 		-10 total points
# player with 0/7 completed/uncompleted tickets, 50 train cards, 3 cars, and
# 		-20 total points
# 16
# 3-player game on turn 233; winners: [2]
# player with 1/7 completed/uncompleted tickets, 19 train cards, 6 cars, and
# 		-13 total points
# player with 0/7 completed/uncompleted tickets, 59 train cards, 12 cars, and
# 		-34 total points
# player with 0/7 completed/uncompleted tickets, 23 train cards, 1 cars, and
# 		-7 total points
# 17
# 3-player game on turn 262; winners: [2]
# player with 1/7 completed/uncompleted tickets, 49 train cards, 16 cars, and
# 		-46 total points
# player with 0/7 completed/uncompleted tickets, 15 train cards, 1 cars, and
# 		-34 total points
# player with 1/7 completed/uncompleted tickets, 18 train cards, 12 cars, and
# 		-22 total points
# 18
# 3-player game on turn 269; winners: [0]
# player with 1/7 completed/uncompleted tickets, 21 train cards, 5 cars, and
# 		-20 total points
# player with 0/7 completed/uncompleted tickets, 57 train cards, 11 cars, and
# 		-42 total points
# player with 0/7 completed/uncompleted tickets, 24 train cards, 0 cars, and
# 		-28 total points
# 19
# 3-player game on turn 296; winners: [2]
# player with 0/7 completed/uncompleted tickets, 25 train cards, 4 cars, and
# 		-28 total points
# player with 2/7 completed/uncompleted tickets, 59 train cards, 14 cars, and
# 		-26 total points
# player with 0/7 completed/uncompleted tickets, 17 train cards, 0 cars, and
# 		-23 total points
# 20
# 3-player game on turn 248; winners: [2]
# player with 0/7 completed/uncompleted tickets, 50 train cards, 16 cars, and
# 		-50 total points
# player with 0/7 completed/uncompleted tickets, 14 train cards, 8 cars, and
# 		-22 total points
# player with 0/7 completed/uncompleted tickets, 15 train cards, 2 cars, and
# 		-2 total points
# 21
# 3-player game on turn 267; winners: [0]
# player with 0/7 completed/uncompleted tickets, 13 train cards, 1 cars, and
# 		-20 total points
# player with 0/7 completed/uncompleted tickets, 31 train cards, 14 cars, and
# 		-33 total points
# player with 0/7 completed/uncompleted tickets, 58 train cards, 15 cars, and
# 		-55 total points
# 22
# 3-player game on turn 255; winners: [2]
# player with 1/7 completed/uncompleted tickets, 23 train cards, 2 cars, and
# 		-37 total points
# player with 0/7 completed/uncompleted tickets, 59 train cards, 11 cars, and
# 		-27 total points
# player with 0/7 completed/uncompleted tickets, 19 train cards, 0 cars, and
# 		-22 total points
# 23
# 3-player game on turn 255; winners: [1]
# player with 0/7 completed/uncompleted tickets, 19 train cards, 0 cars, and
# 		-20 total points
# player with 1/7 completed/uncompleted tickets, 53 train cards, 15 cars, and
# 		-20 total points
# player with 0/7 completed/uncompleted tickets, 31 train cards, 6 cars, and
# 		-21 total points
# 24
# 3-player game on turn 258; winners: [1]
# player with 0/7 completed/uncompleted tickets, 13 train cards, 1 cars, and
# 		-39 total points
# player with 0/7 completed/uncompleted tickets, 14 train cards, 5 cars, and
# 		-10 total points
# player with 0/7 completed/uncompleted tickets, 49 train cards, 18 cars, and
# 		-35 total points
# 25
# 3-player game on turn 243; winners: [1]
# player with 0/7 completed/uncompleted tickets, 35 train cards, 0 cars, and
# 		-7 total points
# player with 2/7 completed/uncompleted tickets, 48 train cards, 9 cars, and
# 		-5 total points
# player with 0/7 completed/uncompleted tickets, 18 train cards, 2 cars, and
# 		-32 total points
# 26
# 3-player game on turn 258; winners: [0, 1]
# player with 0/7 completed/uncompleted tickets, 24 train cards, 2 cars, and
# 		-18 total points
# player with 0/7 completed/uncompleted tickets, 50 train cards, 8 cars, and
# 		-18 total points
# player with 0/7 completed/uncompleted tickets, 27 train cards, 6 cars, and
# 		-19 total points
# 27
# 3-player game on turn 267; winners: [1]
# player with 0/7 completed/uncompleted tickets, 17 train cards, 1 cars, and
# 		-15 total points
# player with 1/7 completed/uncompleted tickets, 37 train cards, 4 cars, and
# 		-4 total points
# player with 0/7 completed/uncompleted tickets, 47 train cards, 2 cars, and
# 		-42 total points
# 28
# 3-player game on turn 291; winners: [0]
# player with 0/7 completed/uncompleted tickets, 31 train cards, 1 cars, and
# 		-7 total points
# player with 0/7 completed/uncompleted tickets, 14 train cards, 4 cars, and
# 		-22 total points
# player with 0/7 completed/uncompleted tickets, 57 train cards, 3 cars, and
# 		-21 total points
# 29
# 3-player game on turn 287; winners: [2]
# player with 2/7 completed/uncompleted tickets, 51 train cards, 9 cars, and
# 		-28 total points
# player with 0/7 completed/uncompleted tickets, 34 train cards, 8 cars, and
# 		-30 total points
# player with 0/7 completed/uncompleted tickets, 17 train cards, 0 cars, and
# 		-14 total points
# 30
# 3-player game on turn 236; winners: [2]
# player with 1/7 completed/uncompleted tickets, 38 train cards, 9 cars, and
# 		-35 total points
# player with 0/7 completed/uncompleted tickets, 29 train cards, 8 cars, and
# 		-36 total points
# player with 0/7 completed/uncompleted tickets, 34 train cards, 0 cars, and
# 		-6 total points
# 31
# 3-player game on turn 262; winners: [1]
# player with 1/7 completed/uncompleted tickets, 55 train cards, 13 cars, and
# 		-42 total points
# player with 0/7 completed/uncompleted tickets, 17 train cards, 0 cars, and
# 		21 total points
# player with 0/7 completed/uncompleted tickets, 30 train cards, 5 cars, and
# 		-33 total points
# 32
# 3-player game on turn 229; winners: [1]
# player with 1/7 completed/uncompleted tickets, 43 train cards, 16 cars, and
# 		-46 total points
# player with 0/7 completed/uncompleted tickets, 9 train cards, 1 cars, and
# 		-9 total points
# player with 0/7 completed/uncompleted tickets, 49 train cards, 21 cars, and
# 		-45 total points
# 33
# 3-player game on turn 231; winners: [0]
# player with 0/7 completed/uncompleted tickets, 29 train cards, 1 cars, and
# 		-16 total points
# player with 0/7 completed/uncompleted tickets, 49 train cards, 15 cars, and
# 		-49 total points
# player with 0/7 completed/uncompleted tickets, 23 train cards, 14 cars, and
# 		-21 total points
# 34
# 3-player game on turn 255; winners: [2]
# player with 1/7 completed/uncompleted tickets, 28 train cards, 0 cars, and
# 		-27 total points
# player with 0/7 completed/uncompleted tickets, 43 train cards, 12 cars, and
# 		-38 total points
# player with 0/7 completed/uncompleted tickets, 32 train cards, 3 cars, and
# 		-1 total points
# 35
# 3-player game on turn 243; winners: [2]
# player with 1/7 completed/uncompleted tickets, 17 train cards, 1 cars, and
# 		-37 total points
# player with 0/7 completed/uncompleted tickets, 37 train cards, 11 cars, and
# 		-38 total points
# player with 0/7 completed/uncompleted tickets, 48 train cards, 10 cars, and
# 		-13 total points
# 36
# 3-player game on turn 270; winners: [0]
# player with 0/7 completed/uncompleted tickets, 12 train cards, 2 cars, and
# 		-14 total points
# player with 0/7 completed/uncompleted tickets, 48 train cards, 5 cars, and
# 		-24 total points
# player with 1/7 completed/uncompleted tickets, 41 train cards, 10 cars, and
# 		-31 total points
# 37
# 3-player game on turn 279; winners: [0]
# player with 1/7 completed/uncompleted tickets, 16 train cards, 2 cars, and
# 		-24 total points
# player with 0/7 completed/uncompleted tickets, 6 train cards, 2 cars, and
# 		-31 total points
# player with 0/7 completed/uncompleted tickets, 42 train cards, 12 cars, and
# 		-47 total points
# 38
# 3-player game on turn 196; winners: [1]
# player with 0/7 completed/uncompleted tickets, 46 train cards, 19 cars, and
# 		-35 total points
# player with 0/7 completed/uncompleted tickets, 33 train cards, 2 cars, and
# 		-1 total points
# player with 0/7 completed/uncompleted tickets, 22 train cards, 13 cars, and
# 		-23 total points
# 39
# 3-player game on turn 280; winners: [1]
# player with 1/7 completed/uncompleted tickets, 20 train cards, 4 cars, and
# 		-27 total points
# player with 0/7 completed/uncompleted tickets, 29 train cards, 0 cars, and
# 		21 total points
# player with 0/7 completed/uncompleted tickets, 52 train cards, 6 cars, and
# 		-34 total points
# 40
# 3-player game on turn 231; winners: [1]
# player with 0/7 completed/uncompleted tickets, 19 train cards, 2 cars, and
# 		-37 total points
# player with 0/7 completed/uncompleted tickets, 25 train cards, 5 cars, and
# 		-8 total points
# player with 0/7 completed/uncompleted tickets, 57 train cards, 23 cars, and
# 		-23 total points
# 41
# 3-player game on turn 244; winners: [1]
# player with 0/7 completed/uncompleted tickets, 15 train cards, 3 cars, and
# 		-42 total points
# player with 2/7 completed/uncompleted tickets, 11 train cards, 1 cars, and
# 		2 total points
# player with 0/7 completed/uncompleted tickets, 45 train cards, 22 cars, and
# 		-54 total points
# 42
# 3-player game on turn 254; winners: [0]
# player with 1/7 completed/uncompleted tickets, 24 train cards, 5 cars, and
# 		0 total points
# player with 0/7 completed/uncompleted tickets, 60 train cards, 12 cars, and
# 		-28 total points
# player with 0/7 completed/uncompleted tickets, 17 train cards, 2 cars, and
# 		-26 total points
# 43
# 3-player game on turn 283; winners: [0]
# player with 2/7 completed/uncompleted tickets, 35 train cards, 7 cars, and
# 		-25 total points
# player with 0/7 completed/uncompleted tickets, 41 train cards, 1 cars, and
# 		-29 total points
# player with 0/7 completed/uncompleted tickets, 26 train cards, 10 cars, and
# 		-25 total points
# 44
# 3-player game on turn 300; winners: [2]
# player with 1/7 completed/uncompleted tickets, 22 train cards, 1 cars, and
# 		-30 total points
# player with 1/7 completed/uncompleted tickets, 59 train cards, 15 cars, and
# 		-47 total points
# player with 0/7 completed/uncompleted tickets, 20 train cards, 1 cars, and
# 		-18 total points
# 45
# 3-player game on turn 270; winners: [0]
# player with 0/7 completed/uncompleted tickets, 14 train cards, 1 cars, and
# ...
# player with 0/7 completed/uncompleted tickets, 54 train cards, 33 cars, and
# 		-73 total points
# player with 0/7 completed/uncompleted tickets, 26 train cards, 6 cars, and
# 		-18 total points
# 52
# 3-player game on turn 168; winners: [1]
# player with 0/7 completed/uncompleted tickets, 19 train cards, 0 cars, and
# 		-25 total points
# player with 0/7 completed/uncompleted tickets, 27 train cards, 6 cars, and
# 		-3 total points
# player with 0/7 completed/uncompleted tickets, 57 train cards, 32 cars, and
# 		-67 total points
# 53
# 3-player game on turn 193; winners: [2]
# player with 0/7 completed/uncompleted tickets, 59 train cards, 24 cars, and
# 		-56 total points
# player with 0/7 completed/uncompleted tickets, 21 train cards, 0 cars, and
# 		-8 total points
# player with 0/7 completed/uncompleted tickets, 21 train cards, 3 cars, and
# 		9 total points
# 54
# 3-player game on turn 183; winners: [0]
# player with 0/7 completed/uncompleted tickets, 22 train cards, 0 cars, and
# 		-16 total points
# player with 0/7 completed/uncompleted tickets, 61 train cards, 26 cars, and
# 		-37 total points
# player with 0/7 completed/uncompleted tickets, 18 train cards, 1 cars, and
# 		-20 total points
# 55
# 3-player game on turn 167; winners: [2]
# player with 0/7 completed/uncompleted tickets, 28 train cards, 11 cars, and
# 		-25 total points
# player with 0/7 completed/uncompleted tickets, 62 train cards, 35 cars, and
# 		-75 total points
# player with 0/7 completed/uncompleted tickets, 11 train cards, 2 cars, and
# 		-15 total points
# 56
# 3-player game on turn 187; winners: [2]
# player with 0/7 completed/uncompleted tickets, 63 train cards, 40 cars, and
# 		-77 total points
# player with 0/7 completed/uncompleted tickets, 8 train cards, 0 cars, and
# 		-34 total points
# player with 0/7 completed/uncompleted tickets, 31 train cards, 19 cars, and
# 		-17 total points
# 57
# 3-player game on turn 207; winners: [1]
# player with 0/7 completed/uncompleted tickets, 15 train cards, 1 cars, and
# 		-21 total points
# player with 0/7 completed/uncompleted tickets, 26 train cards, 7 cars, and
# 		-17 total points
# player with 0/7 completed/uncompleted tickets, 60 train cards, 35 cars, and
# 		-55 total points
# 58
# 3-player game on turn 188; winners: [2]
# player with 0/7 completed/uncompleted tickets, 23 train cards, 11 cars, and
# 		-24 total points
# player with 0/7 completed/uncompleted tickets, 64 train cards, 33 cars, and
# 		-62 total points
# player with 0/7 completed/uncompleted tickets, 14 train cards, 1 cars, and
# 		-20 total points
# 59
# 3-player game on turn 178; winners: [0]
# player with 0/7 completed/uncompleted tickets, 50 train cards, 9 cars, and
# 		-18 total points
# player with 1/7 completed/uncompleted tickets, 13 train cards, 2 cars, and
# 		-24 total points
# player with 0/7 completed/uncompleted tickets, 38 train cards, 9 cars, and
# 		-25 total points
# 60
# 3-player game on turn 205; winners: [0]
# player with 0/7 completed/uncompleted tickets, 13 train cards, 2 cars, and
# 		-16 total points
# player with 0/7 completed/uncompleted tickets, 28 train cards, 1 cars, and
# 		-19 total points
# player with 0/7 completed/uncompleted tickets, 60 train cards, 27 cars, and
# 		-59 total points
# 61
# 3-player game on turn 197; winners: [2]
# player with 0/7 completed/uncompleted tickets, 54 train cards, 24 cars, and
# 		-51 total points
# player with 0/7 completed/uncompleted tickets, 35 train cards, 16 cars, and
# 		-49 total points
# player with 1/7 completed/uncompleted tickets, 14 train cards, 0 cars, and
# 		10 total points
# 62
# 3-player game on turn 212; winners: [0]
# player with 0/7 completed/uncompleted tickets, 22 train cards, 6 cars, and
# 		-5 total points
# player with 0/7 completed/uncompleted tickets, 58 train cards, 27 cars, and
# 		-44 total points
# player with 0/7 completed/uncompleted tickets, 21 train cards, 0 cars, and
# 		-20 total points
# 63
# 3-player game on turn 191; winners: [0, 2]
# player with 0/7 completed/uncompleted tickets, 16 train cards, 5 cars, and
# 		-17 total points
# player with 0/7 completed/uncompleted tickets, 48 train cards, 15 cars, and
# 		-19 total points
# player with 0/7 completed/uncompleted tickets, 37 train cards, 2 cars, and
# 		-17 total points
# 64
# 3-player game on turn 188; winners: [2]
# player with 0/7 completed/uncompleted tickets, 62 train cards, 31 cars, and
# 		-52 total points
# player with 1/7 completed/uncompleted tickets, 26 train cards, 10 cars, and
# 		-38 total points
# player with 0/7 completed/uncompleted tickets, 13 train cards, 2 cars, and
# 		-8 total points
# 65
# 3-player game on turn 165; winners: [1]
# player with 0/7 completed/uncompleted tickets, 19 train cards, 2 cars, and
# 		-13 total points
# player with 0/7 completed/uncompleted tickets, 17 train cards, 8 cars, and
# 		-12 total points
# player with 0/7 completed/uncompleted tickets, 65 train cards, 24 cars, and
# 		-50 total points
# 66
# 3-player game on turn 188; winners: [2]
# player with 0/7 completed/uncompleted tickets, 52 train cards, 21 cars, and
# 		-31 total points
# player with 0/7 completed/uncompleted tickets, 38 train cards, 15 cars, and
# 		-49 total points
# player with 0/7 completed/uncompleted tickets, 11 train cards, 2 cars, and
# 		-8 total points
# 67
# 3-player game on turn 193; winners: [1]
# player with 0/7 completed/uncompleted tickets, 63 train cards, 34 cars, and
# 		-62 total points
# player with 0/7 completed/uncompleted tickets, 12 train cards, 0 cars, and
# 		-4 total points
# player with 0/7 completed/uncompleted tickets, 26 train cards, 11 cars, and
# 		-11 total points
# 68
# 3-player game on turn 166; winners: [1]
# player with 0/7 completed/uncompleted tickets, 2 train cards, 9 cars, and
# 		-30 total points
# player with 0/7 completed/uncompleted tickets, 16 train cards, 1 cars, and
# 		-16 total points
# player with 0/7 completed/uncompleted tickets, 83 train cards, 42 cars, and
# 		-67 total points
# 69
# 3-player game on turn 179; winners: [2]
# player with 0/7 completed/uncompleted tickets, 55 train cards, 26 cars, and
# 		-69 total points
# player with 0/7 completed/uncompleted tickets, 33 train cards, 12 cars, and
# 		-34 total points
# player with 1/7 completed/uncompleted tickets, 13 train cards, 2 cars, and
# 		-3 total points
# 70
# 3-player game on turn 178; winners: [0]
# player with 0/7 completed/uncompleted tickets, 31 train cards, 11 cars, and
# 		-12 total points
# player with 0/7 completed/uncompleted tickets, 16 train cards, 2 cars, and
# 		-26 total points
# player with 0/7 completed/uncompleted tickets, 54 train cards, 31 cars, and
# 		-35 total points
# 71
# 3-player game on turn 190; winners: [1]
# player with 0/7 completed/uncompleted tickets, 50 train cards, 13 cars, and
# 		-33 total points
# player with 0/7 completed/uncompleted tickets, 9 train cards, 0 cars, and
# 		2 total points
# player with 0/7 completed/uncompleted tickets, 44 train cards, 17 cars, and
# 		-47 total points
# 72
# 3-player game on turn 206; winners: [1]
# player with 0/7 completed/uncompleted tickets, 67 train cards, 24 cars, and
# 		-60 total points
# player with 1/7 completed/uncompleted tickets, 19 train cards, 2 cars, and
# 		-7 total points
# player with 0/7 completed/uncompleted tickets, 15 train cards, 2 cars, and
# 		-16 total points
# 73
# 3-player game on turn 202; winners: [1]
# player with 0/7 completed/uncompleted tickets, 27 train cards, 18 cars, and
# 		-32 total points
# player with 1/7 completed/uncompleted tickets, 17 train cards, 1 cars, and
# 		-24 total points
# player with 0/7 completed/uncompleted tickets, 57 train cards, 24 cars, and
# 		-62 total points
# 74
# 3-player game on turn 185; winners: [0]
# player with 0/7 completed/uncompleted tickets, 37 train cards, 8 cars, and
# 		2 total points
# player with 0/7 completed/uncompleted tickets, 63 train cards, 30 cars, and
# 		-67 total points
# player with 0/7 completed/uncompleted tickets, 3 train cards, 0 cars, and
# 		-1 total points
# 75
# 3-player game on turn 183; winners: [0]
# player with 0/7 completed/uncompleted tickets, 11 train cards, 0 cars, and
# 		-8 total points
# player with 0/7 completed/uncompleted tickets, 56 train cards, 27 cars, and
# 		-43 total points
# player with 1/7 completed/uncompleted tickets, 34 train cards, 19 cars, and
# 		-33 total points
# 76
# 3-player game on turn 180; winners: [0]
# player with 0/7 completed/uncompleted tickets, 0 train cards, 1 cars, and
# 		5 total points
# player with 0/7 completed/uncompleted tickets, 50 train cards, 29 cars, and
# 		-66 total points
# player with 0/7 completed/uncompleted tickets, 52 train cards, 41 cars, and
# 		-87 total points
# 77
# 3-player game on turn 171; winners: [2]
# player with 0/7 completed/uncompleted tickets, 23 train cards, 2 cars, and
# 		-26 total points
# player with 0/7 completed/uncompleted tickets, 73 train cards, 40 cars, and
# 		-79 total points
# player with 0/7 completed/uncompleted tickets, 5 train cards, 7 cars, and
# 		-6 total points
# 78
# 3-player game on turn 193; winners: [1]
# player with 0/7 completed/uncompleted tickets, 15 train cards, 14 cars, and
# 		-27 total points
# player with 1/7 completed/uncompleted tickets, 21 train cards, 0 cars, and
# 		3 total points
# player with 0/7 completed/uncompleted tickets, 65 train cards, 34 cars, and
# 		-64 total points
# 79
# 3-player game on turn 203; winners: [1]
# player with 0/7 completed/uncompleted tickets, 58 train cards, 23 cars, and
# 		-26 total points
# player with 0/7 completed/uncompleted tickets, 27 train cards, 4 cars, and
# 		-7 total points
# player with 0/7 completed/uncompleted tickets, 17 train cards, 0 cars, and
# 		-19 total points
# 80
# 3-player game on turn 198; winners: [0]
# player with 1/7 completed/uncompleted tickets, 10 train cards, 0 cars, and
# 		7 total points
# player with 0/7 completed/uncompleted tickets, 49 train cards, 16 cars, and
# 		-17 total points
# player with 0/7 completed/uncompleted tickets, 43 train cards, 12 cars, and
# 		-46 total points
# 81
# 3-player game on turn 202; winners: [0]
# player with 0/7 completed/uncompleted tickets, 8 train cards, 5 cars, and
# 		7 total points
# player with 1/7 completed/uncompleted tickets, 16 train cards, 0 cars, and
# 		-14 total points
# player with 0/7 completed/uncompleted tickets, 78 train cards, 44 cars, and
# 		-95 total points
# 82
# 3-player game on turn 198; winners: [0]
# player with 0/7 completed/uncompleted tickets, 10 train cards, 0 cars, and
# 		-6 total points
# player with 0/7 completed/uncompleted tickets, 48 train cards, 21 cars, and
# 		-23 total points
# player with 0/7 completed/uncompleted tickets, 44 train cards, 23 cars, and
# 		-35 total points
# 83
# 3-player game on turn 181; winners: [2]
# player with 0/7 completed/uncompleted tickets, 33 train cards, 18 cars, and
# 		-36 total points
# player with 0/7 completed/uncompleted tickets, 14 train cards, 0 cars, and
# 		-19 total points
# player with 3/7 completed/uncompleted tickets, 55 train cards, 28 cars, and
# 		-16 total points
# 84
# 3-player game on turn 173; winners: [1]
# player with 0/7 completed/uncompleted tickets, 60 train cards, 27 cars, and
# 		-42 total points
# player with 0/7 completed/uncompleted tickets, 27 train cards, 6 cars, and
# 		2 total points
# player with 0/7 completed/uncompleted tickets, 14 train cards, 1 cars, and
# 		-22 total points
# 85
# 3-player game on turn 232; winners: [0]
# player with 0/7 completed/uncompleted tickets, 34 train cards, 6 cars, and
# 		-6 total points
# player with 1/7 completed/uncompleted tickets, 30 train cards, 1 cars, and
# 		-9 total points
# player with 0/7 completed/uncompleted tickets, 37 train cards, 14 cars, and
# 		-27 total points
# 86
# 3-player game on turn 195; winners: [0]
# player with 0/7 completed/uncompleted tickets, 9 train cards, 0 cars, and
# 		-11 total points
# player with 1/7 completed/uncompleted tickets, 53 train cards, 18 cars, and
# 		-29 total points
# player with 0/7 completed/uncompleted tickets, 41 train cards, 16 cars, and
# 		-25 total points
# 87
# 3-player game on turn 180; winners: [2]
# player with 0/7 completed/uncompleted tickets, 12 train cards, 1 cars, and
# 		-24 total points
# player with 0/7 completed/uncompleted tickets, 52 train cards, 27 cars, and
# 		-45 total points
# player with 0/7 completed/uncompleted tickets, 37 train cards, 12 cars, and
# 		-15 total points
# 88
# 3-player game on turn 171; winners: [0]
# player with 0/7 completed/uncompleted tickets, 17 train cards, 0 cars, and
# 		-1 total points
# player with 0/7 completed/uncompleted tickets, 60 train cards, 19 cars, and
# 		-55 total points
# player with 0/7 completed/uncompleted tickets, 26 train cards, 5 cars, and
# 		-22 total points
# 89
# 3-player game on turn 203; winners: [2]
# player with 1/7 completed/uncompleted tickets, 29 train cards, 7 cars, and
# 		-18 total points
# player with 0/7 completed/uncompleted tickets, 60 train cards, 23 cars, and
# 		-33 total points
# player with 1/7 completed/uncompleted tickets, 13 train cards, 0 cars, and
# 		3 total points
# 90
# 3-player game on turn 189; winners: [2]
# player with 3/7 completed/uncompleted tickets, 11 train cards, 2 cars, and
# 		-16 total points
# player with 0/7 completed/uncompleted tickets, 56 train cards, 25 cars, and
# 		-21 total points
# player with 2/7 completed/uncompleted tickets, 34 train cards, 14 cars, and
# 		-10 total points
# 91
# 3-player game on turn 186; winners: [0]
# player with 0/7 completed/uncompleted tickets, 17 train cards, 0 cars, and
# 		2 total points
# player with 0/7 completed/uncompleted tickets, 62 train cards, 25 cars, and
# 		-50 total points
# player with 0/7 completed/uncompleted tickets, 23 train cards, 8 cars, and
# 		-19 total points
# 92
# 3-player game on turn 200; winners: [1]
# player with 0/7 completed/uncompleted tickets, 70 train cards, 23 cars, and
# 		-53 total points
# player with 0/7 completed/uncompleted tickets, 6 train cards, 3 cars, and
# 		2 total points
# player with 0/7 completed/uncompleted tickets, 27 train cards, 0 cars, and
# 		-7 total points
# 93
# 3-player game on turn 203; winners: [2]
# player with 0/7 completed/uncompleted tickets, 75 train cards, 42 cars, and
# 		-70 total points
# player with 0/7 completed/uncompleted tickets, 5 train cards, 3 cars, and
# 		-17 total points
# player with 0/7 completed/uncompleted tickets, 21 train cards, 0 cars, and
# 		2 total points
# 94
# 3-player game on turn 175; winners: [1]
# player with 0/7 completed/uncompleted tickets, 30 train cards, 5 cars, and
# 		-17 total points
# player with 0/7 completed/uncompleted tickets, 17 train cards, 0 cars, and
# 		-14 total points
# player with 0/7 completed/uncompleted tickets, 54 train cards, 25 cars, and
# 		-66 total points
# 95
# 3-player game on turn 211; winners: [1]
# player with 0/7 completed/uncompleted tickets, 65 train cards, 30 cars, and
# 		-41 total points
# player with 0/7 completed/uncompleted tickets, 17 train cards, 0 cars, and
# 		3 total points
# player with 1/7 completed/uncompleted tickets, 21 train cards, 3 cars, and
# 		-13 total points
# 96
# 3-player game on turn 211; winners: [1]
# player with 0/7 completed/uncompleted tickets, 51 train cards, 17 cars, and
# 		-39 total points
# player with 0/7 completed/uncompleted tickets, 15 train cards, 0 cars, and
# 		3 total points
# player with 1/7 completed/uncompleted tickets, 35 train cards, 7 cars, and
# 		-25 total points
# 97
# 3-player game on turn 198; winners: [0]
# player with 0/7 completed/uncompleted tickets, 21 train cards, 0 cars, and
# 		-8 total points
# player with 0/7 completed/uncompleted tickets, 24 train cards, 5 cars, and
# 		-20 total points
# player with 0/7 completed/uncompleted tickets, 56 train cards, 20 cars, and
# 		-36 total points
# 98
# 3-player game on turn 184; winners: [1]
# player with 0/7 completed/uncompleted tickets, 26 train cards, 7 cars, and
# 		-25 total points
# player with 0/7 completed/uncompleted tickets, 17 train cards, 0 cars, and
# 		1 total points
# player with 0/7 completed/uncompleted tickets, 59 train cards, 24 cars, and
# 		-68 total points
# 99
# 3-player game on turn 187; winners: [1]
# player with 0/7 completed/uncompleted tickets, 42 train cards, 15 cars, and
# 		-29 total points
# player with 1/7 completed/uncompleted tickets, 11 train cards, 1 cars, and
# 		-10 total points
# player with 0/7 completed/uncompleted tickets, 48 train cards, 25 cars, and
# 		-66 total points
# extended training...
# resetting history...

# %%
player_wins
# Out:
# [[12, 34, 54], [12, 37, 52], [40, 49, 15], [61, 32, 8], [62, 35, 5]]

# %% [markdown]
# the network seems to have some issues with training; it seems like the network did okay in earlier stages, but did much worse in later ones

# %%
p0.ai.save_models('test_000_p0_%s.h5')
p1.ai.save_models('test_000_p1_%s.h5')
p2.ai.save_models('test_000_p2_%s.h5')
